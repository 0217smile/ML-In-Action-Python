# %%
x = np.linspace(0, 2*np.pi, 50)
#plt.plot(x, np.sin(x))
#plt.plot(x, np.sin(x), x, np.sin(2*x))
#plt.plot(x, np.sin(x), 'r-.', x, np.sin(2*x), 'g--o')
plt.subplot(2,2,1) #行，列，活跃区域
plt.plot(x, np.sin(x), 'r-o')
plt.subplot(2,2,2)
plt.plot(x, np.cos(x), 'y-s')
plt.subplot(2,2,3)
plt.plot(x, np.sin(2*x), 'b--^')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#散点图
x = np.linspace(0, 2*np.pi, 50)
y = np.sin(x)
plt.scatter(x, y)
plt.show()

# %%
#散点图
x = np.random.rand(1000)
y = np.random.rand(1000)
size = np.random.rand(1000)*50
colour = np.random.rand(1000)
plt.scatter(x, y, size, colour)
plt.colorbar()
plt.show()

# %%
#直方图
x = np.random.randn(1000)#1000个数据
plt.hist(x, 30) #hist()传入一个包含数据的数组。第二个参数代表数据容器的个数。值越大，图形上的数据条就越多。
plt.show() #直方图 纵轴代表各组数据有多少个 横轴才是将 x 数组各个值分的组

# %%
# 添加标题，坐标轴标记和图例
x = np.linspace(0, 2*np.pi, 50)
plt.plot(x, np.sin(x), 'r-.', label='Sin(x)')
plt.plot(x, np.cos(x), 'b--^', label='Cos(x)')
plt.legend()
plt.xlabel('Rads')
plt.ylabel('Amplitude')
plt.title('Sin And Cos Waves')
plt.show()
